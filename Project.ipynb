# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

print('ready')
# Out:
# ready

# %%
url="./Data set/africa_food_prices.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# 0           5       KG      4  2015   90.0                 NaN
# 1           5       KG      5  2015   96.0                 NaN
# 2           5       KG      6  2015   96.0                 NaN
# 3           5       KG      7  2015   83.0                 NaN
# 4           5       KG      8  2015   80.0                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
#  15  month               956779 non-null  int64
#  16  year                956779 non-null  int64
#  17  price               956779 non-null  float64
#  18  mp_commoditysource  0 non-null       float64
# dtypes: float64(4), int64(8), object(7)
# memory usage: 138.7+ MB

# %%
df.drop(["Unnamed: 0","mp_commoditysource"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (956779, 17)

# %%
df.columns
# Out:
# Index(['country_id', 'country', 'state_id', 'state', 'market_id', 'market',
#        'produce_id', 'produce', 'currency_id', 'currency', 'pt_id',
#        'market_type', 'um_unit_id', 'quantity', 'month', 'year', 'price'],
#       dtype='object')

# %%
df.state.replace(np.nan, "No State",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country_id   956779 non-null  float64
#  1   country      956779 non-null  object
#  2   state_id     956779 non-null  int64
#  3   state        956779 non-null  object
#  4   market_id    956779 non-null  int64
#  5   market       956779 non-null  object
#  6   produce_id   956779 non-null  int64
#  7   produce      956779 non-null  object
#  8   currency_id  956779 non-null  float64
#  9   currency     956779 non-null  object
#  10  pt_id        956779 non-null  int64
#  11  market_type  956779 non-null  object
#  12  um_unit_id   956779 non-null  int64
#  13  quantity     956779 non-null  object
#  14  month        956779 non-null  int64
#  15  year         956779 non-null  int64
#  16  price        956779 non-null  float64
# dtypes: float64(3), int64(7), object(7)
# memory usage: 124.1+ MB

# %%
print(df.produce)
# Out:
# 0                   Rice - Retail
# 1                   Rice - Retail
# 2                   Rice - Retail
# 3                   Rice - Retail
# 4                   Rice - Retail
#                    ...
# 956774     Beans (sugar) - Retail
# 956775        Toothpaste - Retail
# 956776      Laundry soap - Retail
# 956777     Handwash soap - Retail
# 956778    Fish (kapenta) - Retail
# Name: produce, Length: 956779, dtype: object

# %%
type(df.produce[0])
# Out:
# str

# %%
df.produce[0]
# Out:
# 'Rice - Retail'

# %%
temp = df['produce'].str.split("- ", n=1, expand=True)

# %%
temp.head(3)
# Out:
#        0       1
# 0  Rice   Retail
# 1  Rice   Retail
# 2  Rice   Retail

# %%
df['produce'] = temp[0]

# %%
df.head(3)
# Out:
#    country_id  country  state_id  state  market_id   market  produce_id  \
# 0         4.0  Algeria       344  Alger       1794  Algiers          52
# 1         4.0  Algeria       344  Alger       1794  Algiers          52
# 2         4.0  Algeria       344  Alger       1794  Algiers          52
#
#   produce  currency_id currency  pt_id market_type  um_unit_id quantity  \
# 0   Rice           0.0      DZD     15      Retail           5       KG
# 1   Rice           0.0      DZD     15      Retail           5       KG
# 2   Rice           0.0      DZD     15      Retail           5       KG
#
#    month  year  price
# 0      4  2015   90.0
# 1      5  2015   96.0
# 2      6  2015   96.0

# %%
df.isnull().sum()
# Out:
# country_id     0
# country        0
# state_id       0
# state          0
# market_id      0
# market         0
# produce_id     0
# produce        0
# currency_id    0
# currency       0
# pt_id          0
# market_type    0
# um_unit_id     0
# quantity       0
# month          0
# year           0
# price          0
# dtype: int64

# %%
df.describe()
# Out:
#           country_id       state_id      market_id     produce_id  \
# count  956779.000000  956779.000000  956779.000000  956779.000000
# mean     1961.192782   22287.911831    1392.594222     186.141214
# std     10404.034922   98565.608270    1027.751212     165.401303
# min         4.000000       0.000000     101.000000      50.000000
# 25%        90.000000    1836.000000     528.000000      67.000000
# 50%       155.000000    2209.000000    1078.000000     105.000000
# 75%       205.000000   21971.000000    2281.000000     262.000000
# max     70001.000000  900003.000000    6081.000000     887.000000
#
#        currency_id          pt_id     um_unit_id          month  \
# count     956779.0  956779.000000  956779.000000  956779.000000
# mean           0.0      14.926716      14.017183       6.381471
# std            0.0       0.263570      24.437728       3.418025
# min            0.0      14.000000       5.000000       1.000000
# 25%            0.0      15.000000       5.000000       3.000000
# 50%            0.0      15.000000       5.000000       6.000000
# 75%            0.0      15.000000       9.000000       9.000000
# max            0.0      17.000000     175.000000      12.000000
#
#                 year         price
# count  956779.000000  9.567790e+05
# mean     2015.704015  4.128833e+03
# std         4.603829  1.381840e+05
# min      1990.000000  0.000000e+00
# 25%      2013.000000  6.500000e+01
# 50%      2017.000000  2.505714e+02
# 75%      2020.000000  7.221005e+02
# max      2021.000000  1.725000e+07

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.year.unique()
# Out:
# array([2015, 2016, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2017, 2018,
#        2019, 2020, 2002, 2003, 2005, 2006, 2007, 2021, 2004, 2000, 2001,
#        1994, 1995, 1996, 1997, 1998, 1999, 1992, 1993, 1990, 1991],
#       dtype=int64)

# %%
df.year.value_counts()
# Out:
# 2020    156199
# 2019     99606
# 2021     91234
# 2018     81720
# 2015     71853
# 2017     66916
# 2014     65238
# 2013     61206
# 2016     52378
# 2012     48916
# 2011     36103
# 2010     27993
# 2009     24725
# 2008     20968
# 2007     15266
# 2006      9421
# 2005      5832
# 2004      4750
# 2003      4356
# 2002      2153
# 2001      1770
# 2000      1319
# 1998      1224
# 1999      1182
# 1997      1065
# 1996      1045
# 1995       924
# 1994       843
# 1993       152
# 1992       148
# 1990       140
# 1991       134
# Name: year, dtype: int64

# %%
df.country.describe()
# Out:
# count     956779
# unique        42
# top       Rwanda
# freq      137746
# Name: country, dtype: object

# %%
df2= df[df["year"]>2018]
df2.head()
# Out:
#       country_id country  state_id   state  market_id  market  produce_id  \
# 1925         8.0  Angola       408  Luanda       2593  Luanda          55
# 1926         8.0  Angola       408  Luanda       2593  Luanda          55
# 1927         8.0  Angola       408  Luanda       2593  Luanda          55
# 1928         8.0  Angola       408  Luanda       2593  Luanda          55
# 1929         8.0  Angola       408  Luanda       2593  Luanda          55
#
#      produce  currency_id currency  pt_id market_type  um_unit_id quantity  \
# 1925  Bread           0.0      AOA     15      Retail          33     Unit
# 1926  Bread           0.0      AOA     15      Retail          33     Unit
# 1927  Bread           0.0      AOA     15      Retail          33     Unit
# 1928  Bread           0.0      AOA     15      Retail          33     Unit
# 1929  Bread           0.0      AOA     15      Retail          33     Unit
#
#       month  year   price
# 1925      1  2019  100.10
# 1926      2  2019  100.25
# 1927      3  2019  100.45
# 1928      4  2019  100.83
# 1929      5  2019  100.83

# %%
df3= df2[df2["country"] == "Nigeria"]
df3.head()
# Out:
#         country_id  country  state_id    state  market_id market  produce_id  \
# 605333       182.0  Nigeria      2211  Adamawa       1980   Mubi          55
# 605334       182.0  Nigeria      2211  Adamawa       1980   Mubi          55
# 605335       182.0  Nigeria      2211  Adamawa       1980   Mubi          55
# 605336       182.0  Nigeria      2211  Adamawa       1980   Mubi          55
# 605337       182.0  Nigeria      2211  Adamawa       1980   Mubi          55
#
#        produce  currency_id currency  pt_id market_type  um_unit_id quantity  \
# 605333  Bread           0.0      NGN     15      Retail          33     Unit
# 605334  Bread           0.0      NGN     15      Retail          33     Unit
# 605335  Bread           0.0      NGN     15      Retail          33     Unit
# 605336  Bread           0.0      NGN     15      Retail          33     Unit
# 605337  Bread           0.0      NGN     15      Retail          33     Unit
#
#         month  year  price
# 605333      2  2019  375.0
# 605334      3  2019  375.0
# 605335      4  2019  375.0
# 605336      8  2019  375.0
# 605337      9  2019  375.0

# %%
df3.produce.value_counts()
# Out:
# Millet                          1254
# Rice (local)                    1219
# Rice (imported)                 1104
# Yam                             1070
# Oil (palm)                       890
# Maize (white)                    736
# Sorghum (white)                  728
# Sorghum (brown)                  726
# Cowpeas (white)                  725
# Groundnuts (shelled)             721
# Gari (white)                     717
# Maize (yellow)                   683
# Cowpeas (brown)                  672
# Cassava meal (gari, yellow)      638
# Fish                             512
# Sugar                            512
# Tomatoes                         512
# Onions                           512
# Meat (beef)                      512
# Groundnuts                       512
# Eggs                             512
# Salt                             512
# Oil (vegetable)                  512
# Beans (white)                    512
# Milk                             512
# Maize flour                      512
# Sorghum                          512
# Meat (goat)                      512
# Oranges                          508
# Watermelons                      508
# Beans (red)                      504
# Bananas                          500
# Cowpeas                          476
# Bread                            394
# Fuel (petrol-gasoline)           379
# Fuel (diesel)                    379
# Spinach                          359
# Rice (milled, local)              70
# Yam (Abuja)                       22
# Name: produce, dtype: int64

# %%
z= df3["produce"].value_counts().head()
z
# Out:
# Millet              1254
# Rice (local)        1219
# Rice (imported)     1104
# Yam                 1070
# Oil (palm)           890
# Name: produce, dtype: int64

# %%
plt.bar(z.index,z.values,color='g')
for i in range(len(z)):
    plt.text(i,z[i],z[i],ha='center')
    plt.title("Most purchased products in Nigeria")

# %%
df3.sort_values(by=["price"], ascending=False)[["state","produce","price"]]
# Out:
#          state   produce    price
# 609098   Borno      Yam   89000.0
# 623537  Kaduna      Yam   83000.0
# 609097   Borno      Yam   83000.0
# 623536  Kaduna      Yam   78750.0
# 609107   Borno      Yam   77500.0
# ...        ...       ...      ...
# 641932    Yobe  Spinach      20.0
# 641933    Yobe  Spinach      20.0
# 651217    Yobe  Spinach      20.0
# 641918    Yobe  Spinach      20.0
# 639129    Yobe  Spinach      10.0
#
# [23150 rows x 3 columns]

# %%
temp2=pd.pivot_table(df3,index=["produce"], values="price")
temp2
# Out:
#                                      price
# produce
# Bananas                         188.903019
# Beans (red)                     299.485119
# Beans (white)                   288.380859
# Bread                           292.974851
# Cassava meal (gari, yellow)    8882.883210
# Cowpeas                         248.865824
# Cowpeas (brown)               11381.129071
# Cowpeas (white)               10797.010942
# Eggs                           1048.816905
# Fish                            491.098828
# Fuel (diesel)                   224.938450
# Fuel (petrol-gasoline)          148.161790
# Gari (white)                   7632.513229
# Groundnuts                      386.308594
# Groundnuts (shelled)          15600.022226
# Maize (white)                  6645.657158
# Maize (yellow)                 6781.591663
# Maize flour                     202.569336
# Meat (beef)                    1138.001172
# Meat (goat)                    1198.390039
# Milk                             61.191797
# Millet                         4359.739642
# Oil (palm)                      457.089459
# Oil (vegetable)                 421.141406
# Onions                           99.827344
# Oranges                         136.549675
# Rice (imported)                6998.559161
# Rice (local)                   9803.654150
# Rice (milled, local)          28605.840040
# Salt                            169.184961
# Sorghum                         150.498047
# Sorghum (brown)                6745.986316
# Sorghum (white)                6819.525414
# Spinach                         101.429526
# Sugar                           527.222266
# Tomatoes                         74.343359
# Watermelons                     266.185703
# Yam                            7050.184053
# Yam (Abuja)                    7256.796455

# %%
R=temp2.plot.bar()
plt.title("Price of products in Nigeria")
# Out:
# Text(0.5, 1.0, 'Price of products in Nigeria')

# %%
pd.pivot_table(df3,index=["state", "produce"], values=["quantity","price"])
# Out:
#                                              price
# state   produce
# Abia    Bread                           100.000000
#         Cassava meal (gari, yellow)   18354.240000
#         Cowpeas (brown)               27141.632000
#         Cowpeas (white)               25125.130750
#         Fuel (diesel)                   256.375000
# ...                                            ...
# Zamfara Rice (local)                  16748.736609
#         Rice (milled, local)          25533.452150
#         Sorghum (brown)                6319.320140
#         Sorghum (white)                7393.777377
#         Yam                           10473.456976
#
# [267 rows x 1 columns]
